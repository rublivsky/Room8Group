# %%
import pandas as pd

df = pd.read_csv('/home/redmoon/Documents/Dev/Room8Group/data/Merged.csv')

# %%
# Filter out rows where 'revenue_vgi' is 0
df = df[df['revenue_vgi'] != 0]
# Filter out rows where 'platforms' is null
df = df[df['platforms'].notnull()]

# Drop unnecessary columns
df = df.drop(columns=['game_id', 'igdb_id', 'name_y', 'released_y'])
df = df.rename(columns={'name_x': 'name', 'released_x': 'released'})
# Display the updated DataFrame
df
# Out:
#      vgi_id                                               name    released  \
# 0    731128  Atelier Yumia The Alchemist of Memories  the E...  2025-03-21
# 1    743106                            Assassins Creed Shadows  2025-03-20
# 2    690290                            BLEACH Rebirth of Souls  2025-03-20
# 3    717914                                        Wreckfest 2  2025-03-20
# 6    746851                                           WWE 2K25  2025-03-13
# ..      ...                                                ...         ...
# 308  626389                                  Minecraft Legends  2023-04-18
# 314  625025                                 EA SPORTS PGA TOUR  2023-04-07
# 316  726583                 Melon Journey Bittersweet Memories  2023-04-06
# 319  617187                                    Resident Evil 4  2023-03-24
# 320  640928  Atelier Ryza 3 Alchemist of the End  the Secre...  2023-03-24
#
# ...

# %%
df.to_csv('/home/redmoon/Documents/Dev/Room8Group/data/PreFinal.csv', index=False)
